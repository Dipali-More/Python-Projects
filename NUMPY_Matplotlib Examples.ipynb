# %%
import numpy as np

# %%
arr1=np.array([[1,2,3,4],[6,7,8,9]])
arr1
# Out:
# array([[1, 2, 3, 4],
#        [6, 7, 8, 9]])

# %%
print(arr1.shape)
# Out:
# (2, 4)

# %%
arr1=np.array([[1,2,3,4,6,7,8,9]])

# %%
arr1
# Out:
# array([[1, 2, 3, 4, 6, 7, 8, 9]])

# %%
ss=arr1.reshape(2,4)
ss
# Out:
# array([[1, 2, 3, 4],
#        [6, 7, 8, 9]])

# %%
arr1.reshape(4,2)
# Out:
# array([[1, 2],
#        [3, 4],
#        [6, 7],
#        [8, 9]])

# %%
arr1=np.array([[1,2,3,4,6,7,8,9]])
arr1
# Out:
# array([[1, 2, 3, 4, 6, 7, 8, 9]])

# %%
for i in ss:
    print(i)
# Out:
# [1 2 3 4]
# [6 7 8 9]

# %%
arr1=([1,2,3])
arr2=([4,5,6])
arr3=np.concatenate((arr1,arr2))
arr3
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr1=([1,2,3])
arr2=([4,5,6])
arr3=np.concatenate((arr1,arr2),axis=0)
arr3
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr1=([[1,2,3],[3,4,5]])
arr2=([[4,5,6],[5,6,7]])
arr3=np.concatenate((arr1,arr2),axis=0)
arr3
# Out:
# array([[1, 2, 3],
#        [3, 4, 5],
#        [4, 5, 6],
#        [5, 6, 7]])

# %%
arr1=([[1,2,3],[3,4,5]])
arr2=([[4,5,6],[5,6,7]])
arr3=np.concatenate((arr1,arr2),axis=1)
arr3
# Out:
# array([[1, 2, 3, 4, 5, 6],
#        [3, 4, 5, 5, 6, 7]])

# %%
arr1=np.array([1,2,3,4,6,7,8,9])
arr2=np.array_split(arr1,4)
arr2
# Out:
# [array([1, 2]), array([3, 4]), array([6, 7]), array([8, 9])]

# %%
arr1=np.array([1,2,3,4,6,7,8,9])
arr2=np.array_split(arr1,3)
arr2
# Out:
# [array([1, 2, 3]), array([4, 6, 7]), array([8, 9])]

# %%
#search
arr1=np.array([1,2,3,4,6,7,8,9])
np.where(arr1==4)
# Out:
# (array([3], dtype=int64),)

# %%
#search
arr1=np.array([1,2,3,4,6,7,8,9])
np.where(arr1==7)
# Out:
# (array([5], dtype=int64),)

# %%
#search
arr1=np.array([1,2,3,4,6,7,8,9])
np.where(arr1<=7)
# Out:
# (array([0, 1, 2, 3, 4, 5], dtype=int64),)

# %%
num1=4
num2=6

# %%
np.lcm(4,6)
# Out:
# 12

# %%
np.sin(np.pi/2)
# Out:
# 1.0

# %%
np.lcm(144,62)
# Out:
# 4464

# %%
from numpy import random
random.randint(100,size=6)
# Out:
# array([94, 96, 27, 41, 45, 78])

# %%
from numpy import random
random.randint(100,size=6)
# Out:
# array([41, 68,  7, 35, 88, 53])

# %%
from numpy import random
random.randint(10,size=6)

# %% [markdown]
# MATPLOT LIB

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
xpoint=np.array([0,6])
ypoint=np.array([0,200])
plt.plot(xpoint,ypoint)

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint)

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='o')

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='*')

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='*',mfc='r')

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='*',mec='r')

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='*',mec='r',mfc='r',ms=10)

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='*',mec='r',mfc='r',ms=10,linestyle='dotted')

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='*',mec='r',mfc='r',ms=10,linestyle='dashed')

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='*',mec='r',mfc='r',ms=10,linestyle='dashed',color='r')

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='*',mec='r',mfc='r',ms=10,linestyle='dashed',color='r',linewidth=3)

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='*',mec='r',mfc='r',ms=10,linestyle='dashed',color='r',linewidth=3)
plt.xlabel("x axis data")
plt.ylabel("y axis data")
# Out:
# Text(0, 0.5, 'y axis data')

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='*',mec='r',mfc='r',ms=10,linestyle='dashed',color='r',linewidth=3)
plt.xlabel("x axis data")
plt.ylabel("y axis data")
plt.title("random data",loc='right')
# Out:
# Text(1.0, 1.0, 'random data')

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='*',mec='r',mfc='r',ms=10,linestyle='dashed',color='r',linewidth=3)
plt.xlabel("x axis data")
plt.ylabel("y axis data")
plt.title("random data",loc='right')
plt.grid()

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='*',mec='r',mfc='r',ms=10,linestyle='dashed',color='r',linewidth=3)
plt.xlabel("x axis data")
plt.ylabel("y axis data")
plt.title("random data",loc='right')
plt.grid(axis='x')

# %%
xpoint=np.array([1,6,8,9])
ypoint=np.array([3,5,3,1])
plt.plot(xpoint,ypoint,marker='*',mec='r',mfc='r',ms=10,linestyle='dashed',color='r',linewidth=3)
plt.xlabel("x axis data")
plt.ylabel("y axis data")
plt.title("random data",loc='right')
plt.grid(axis='y',color='g')

# %%
x=np.array([1,6,8,9])
y=np.array([3,5,3,1])
plt.subplot(1,2,2)
plt.plot(x,y)
x=np.array([8,9,1,6])
y=np.array([3,1,3,5])
plt.subplot(1,2,1)
plt.plot(x,y)

# %%
x=np.array([1,6,8,9])
y=np.array([3,5,3,1])
plt.scatter(x,y)

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,5,3,1])
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,5,3,1])
plt.bar(x,y,color='r')
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,5,3,1])
plt.bar(x,y,color='r',width=0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,5,3,1])
plt.barh(x,y,color='r')
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,5,3,1])
plt.barh(x,y,color='r',height=0.4)
# Out:
# <BarContainer object of 4 artists>

# %%
import pandas as pd

# %%
df=pd.read_csv("countrydata.csv")

# %%
df
# Out:
#     Unnamed: 0                        Region[30]  Total cases  Total deaths  \
# 0            0                    European Union    179537758       1185108
# 1            1                     North America    103783777       1133607
# 2            2                      Other Europe     57721948        498259
# 3            3                     South America     65835789       1313061
# 4            4           Russia and Central Asia     25646533        434988
# 5            5                   Central America     11338600        380660
# 6            6                       Middle East     22549784        238106
# 7            7  Oceania and islands in East Asia     60806544        318455
# 8            8                         Caribbean      2605473         26237
# 9            9                        South Asia     50347136        620218
# 10          10                      North Africa      3727346         83873
# ...

# %%
df.plot(x='Region[30]', y='Total cases',kind='bar')
# Out:
# <Axes: xlabel='Region[30]'>

# %%
df.plot(x='Region[30]', y='Population millions',kind='pie')
# Out:
# <Axes: ylabel='Population millions'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Region[30]', 'Total cases', 'Total deaths',
#        'Cases per million', 'Deaths per million', 'Current weekly cases',
#        'Current weekly deaths', 'Population millions', 'Vaccinated %[31]'],
#       dtype='object')

# %%
df.plot(x='Region[30]', y='Total cases',kind='scatter')
# Out:
# <Axes: xlabel='Region[30]', ylabel='Total cases'>
